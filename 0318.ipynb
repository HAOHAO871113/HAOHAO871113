# %% [markdown]
# <a href="https://colab.research.google.com/github/HAOHAO871113/HAOHAO871113/blob/main/0318.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/PacktPublishing/Learning-Pandas-Second-Edition/master/data/msft.csv
# Out:
# --2022-03-18 05:57:42--  https://raw.githubusercontent.com/PacktPublishing/Learning-Pandas-Second-Edition/master/data/msft.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 153109 (150K) [text/plain]
# Saving to: ‘msft.csv’
#
# msft.csv            100%[===================>] 149.52K  --.-KB/s    in 0.04s
#
# 2022-03-18 05:57:42 (4.10 MB/s) - ‘msft.csv’ saved [153109/153109]

# %% [markdown]
# ### **印出剛剛所下載下來的CSV檔案的前五筆資料**

# %%
# !head -n 5 msft.csv
# Out:
# Date,Open,High,Low,Close,Volume
# 7/21/2014,83.46,83.53,81.81,81.93,2359300
# 7/18/2014,83.3,83.4,82.52,83.35,4020800
# 7/17/2014,84.35,84.63,83.33,83.63,1974000
# 7/16/2014,83.77,84.91,83.66,84.91,1755600

# %% [markdown]
# ### **讀取CSV檔後印出五筆資料且用表格模式呈現**
#
# ---

# %%
import pandas as pd
msft = pd.read_csv("./msft.csv")
msft[:5]
# Out:
#         Date   Open   High    Low  Close   Volume
# 0  7/21/2014  83.46  83.53  81.81  81.93  2359300
# 1  7/18/2014  83.30  83.40  82.52  83.35  4020800
# 2  7/17/2014  84.35  84.63  83.33  83.63  1974000
# 3  7/16/2014  83.77  84.91  83.66  84.91  1755600
# 4  7/15/2014  84.30  84.38  83.20  83.58  1874700

# %%
# !mv ./msft.csv ./G100A006.csv

# %%
msft = pd.read_csv("./G100A006.csv")
msft[:3]
# Out:
#         Date   Open   High    Low  Close   Volume
# 0  7/21/2014  83.46  83.53  81.81  81.93  2359300
# 1  7/18/2014  83.30  83.40  82.52  83.35  4020800
# 2  7/17/2014  84.35  84.63  83.33  83.63  1974000

# %%
df = pd.read_csv("./G100A006.csv")
df[:3]
# Out:
#         Date   Open   High    Low  Close   Volume
# 0  7/21/2014  83.46  83.53  81.81  81.93  2359300
# 1  7/18/2014  83.30  83.40  82.52  83.35  4020800
# 2  7/17/2014  84.35  84.63  83.33  83.63  1974000

# %%
msft.dtypes
# Out:
# Date       object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume      int64
# dtype: object

# %% [markdown]
# ### **指定要印出的名稱**

# %%
df = pd.read_csv("./G100A006.csv",
                 header=0,
                 names=['date', 'open', 'high', 'low', 
                        'close', 'volume'])
df[:5]
# Out:
#         date   open   high    low  close   volume
# 0  7/21/2014  83.46  83.53  81.81  81.93  2359300
# 1  7/18/2014  83.30  83.40  82.52  83.35  4020800
# 2  7/17/2014  84.35  84.63  83.33  83.63  1974000
# 3  7/16/2014  83.77  84.91  83.66  84.91  1755600
# 4  7/15/2014  84.30  84.38  83.20  83.58  1874700

# %% [markdown]
# ### **指定增加特定列表**

# %%
df2 = pd.read_csv("./G100A006.csv", 
                  usecols=['Date', 'Close'], 
                  index_col=['Date'])
df2[:5]
# Out:
#            Close
# Date
# 7/21/2014  81.93
# 7/18/2014  83.35
# 7/17/2014  83.63
# 7/16/2014  84.91
# 7/15/2014  83.58

# %% [markdown]
# ### **分隔數據**

# %%
df = pd.read_table("./G100A006.csv", sep=',')
df[:5]
# Out:
#         Date   Open   High    Low  Close   Volume
# 0  7/21/2014  83.46  83.53  81.81  81.93  2359300
# 1  7/18/2014  83.30  83.40  82.52  83.35  4020800
# 2  7/17/2014  84.35  84.63  83.33  83.63  1974000
# 3  7/16/2014  83.77  84.91  83.66  84.91  1755600
# 4  7/15/2014  84.30  84.38  83.20  83.58  1874700

# %%
df.to_csv("./G100A006.txt", sep='|')

# !head -n 5 ./G100A006.txt
# Out:
# |Date|Open|High|Low|Close|Volume
# 0|7/21/2014|83.46|83.53|81.81|81.93|2359300
# 1|7/18/2014|83.3|83.4|82.52|83.35|4020800
# 2|7/17/2014|84.35|84.63|83.33|83.63|1974000
# 3|7/16/2014|83.77|84.91|83.66|84.91|1755600

# %% [markdown]
# # **以xlsx格式進行讀取與寫入數據**

# %% [markdown]
# ### **讀取xlsx檔後印出五筆資料**

# %%
df = pd.read_excel("stocks.xlsx")
df[:5]
# Out:
#         Date   Open   High    Low  Close   Volume
# 0 2014-07-21  83.46  83.53  81.81  81.93  2359300
# 1 2014-07-18  83.30  83.40  82.52  83.35  4020800
# 2 2014-07-17  84.35  84.63  83.33  83.63  1974000
# 3 2014-07-16  83.77  84.91  83.66  84.91  1755600
# 4 2014-07-15  84.30  84.38  83.20  83.58  1874700

# %% [markdown]
# ### **讀取xlsx的第二表單appl**

# %%
# read from the aapl worksheet
aapl = pd.read_excel("stocks.xlsx", sheet_name='aapl')
aapl[:5]
# Out:
#         Date   Open   High    Low  Close    Volume
# 0 2014-07-21  94.99  95.00  93.72  93.94  38887700
# 1 2014-07-18  93.62  94.74  93.02  94.43  49898600
# 2 2014-07-17  95.03  95.28  92.57  93.09  57152000
# 3 2014-07-16  96.97  97.10  94.74  94.78  53396300
# 4 2014-07-15  96.80  96.85  95.03  95.32  45477900

# %%
df.to_excel("stocks_msft.xlsx", sheet_name='MSFT')

# %%
from pandas import ExcelWriter
with ExcelWriter("all_stocks.xlsx") as writer:
    aapl.to_excel(writer, sheet_name='AAPL')
    df.to_excel(writer, sheet_name='MSFT')

# %%
df.to_excel("msft2.xlsx")

# %% [markdown]
# ### **Reading and writing JSON files**

# %%
# !wget https://raw.githubusercontent.com/PacktPublishing/Learning-Pandas-Second-Edition/master/data/stocks.json
# Out:
# --2022-03-18 07:30:27--  https://raw.githubusercontent.com/PacktPublishing/Learning-Pandas-Second-Edition/master/data/stocks.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 403 [text/plain]
# Saving to: ‘stocks.json’
#
# stocks.json         100%[===================>]     403  --.-KB/s    in 0s
#
# 2022-03-18 07:30:27 (17.6 MB/s) - ‘stocks.json’ saved [403/403]

# %% [markdown]
# ### **讀取stocks.json檔**

# %%
df[:5].to_json("stocks.json")
# !cat stocks.json # osx or Linux
# Out:
# {"Date":{"0":1405900800000,"1":1405641600000,"2":1405555200000,"3":1405468800000,"4":1405382400000},"Open":{"0":83.46,"1":83.3,"2":84.35,"3":83.77,"4":84.3},"High":{"0":83.53,"1":83.4,"2":84.63,"3":84.91,"4":84.38},"Low":{"0":81.81,"1":82.52,"2":83.33,"3":83.66,"4":83.2},"Close":{"0":81.93,"1":83.35,"2":83.63,"3":84.91,"4":83.58},"Volume":{"0":2359300,"1":4020800,"2":1974000,"3":1755600,"4":1874700}}

# %% [markdown]
# ### **讀取json檔並用表格顯示**

# %%
df_from_json = pd.read_json("stocks.json")
df_from_json[:5]
# Out:
#         Date   Open   High    Low  Close   Volume
# 0 2014-07-21  83.46  83.53  81.81  81.93  2359300
# 1 2014-07-18  83.30  83.40  82.52  83.35  4020800
# 2 2014-07-17  84.35  84.63  83.33  83.63  1974000
# 3 2014-07-16  83.77  84.91  83.66  84.91  1755600
# 4 2014-07-15  84.30  84.38  83.20  83.58  1874700

# %% [markdown]
# ### **讀取xlsx檔案將前面兩行寫入至html，最後印出前十筆資料**

# %%
df = pd.read_excel("stocks.xlsx")
# write the first two rows to HTML
df.head(2).to_html("stocks.html")
# check the first 28 lines of the output
# !head -n 10 stocks.html # max or Linux
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Date</th>
#       <th>Open</th>
#       <th>High</th>
#       <th>Low</th>
#       <th>Close</th>
#       <th>Volume</th>
